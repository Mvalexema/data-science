# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('tech_stocks1.csv')

print (df.head())
# Out:
#        RIC           Name              Activity    MarketCap  EBITDA_M  \
# 0    APP.O  Applovin Corp  Application Software  14006283568     35.63
# 1  OPRA.OQ      Opera Ltd  Application Software   1028597961     17.78
# 2   DDOG.O    Datadog Inc  Application Software  40412102148     -1.44
# 3   ADBE.O      Adobe Inc  Application Software  2.71605E+11     39.58
# 4   WDAY.O    Workday Inc  Application Software  74492120000      2.23
#
#    1_year    YTD  EV_EBITDA_3F  EV_Revenues_1F  EV_Revenues_2F  Revenue_gr_24  \
# 0  290.54   4.67          8.13            5.17            4.44           0.17
# 1   84.64 -12.32          7.59            2.41            2.09           0.15
# 2   77.72   1.33         49.23           18.41           14.84           0.24
# 3   73.14  -0.01         20.24           12.43           11.10           0.12
# 4   73.14   2.60         24.09            9.73            8.36           0.16
#
#    Revenue_gr_25  EBITDAgr25  min__to_av_chg_price
# ...

# %%
df.describe()
# Out:
#          EBITDA_M      1_year         YTD  EV_EBITDA_3F  EV_Revenues_1F  \
# count  425.000000  421.000000  426.000000    425.000000      426.000000
# mean    12.599741   22.112779   -3.466573     18.026141        5.491174
# std     25.827985   50.355701    6.609846     18.040079        4.598585
# min   -106.600000  -76.010000  -30.590000      0.140000        0.050000
# 25%      0.230000   -9.480000   -6.972500      8.400000        2.000000
# 50%     14.930000   12.980000   -2.955000     12.320000        4.210000
# 75%     28.130000   43.860000    0.855000     20.990000        7.407500
# max     78.320000  322.080000   19.450000    141.410000       22.880000
#
#        EV_Revenues_2F  Revenue_gr_24  Revenue_gr_25  EBITDAgr25  \
# count      426.000000     426.000000     426.000000  426.000000
# mean         4.811526       0.113592       0.127981    0.412934
# std          3.847774       0.107861       0.090804    1.303251
# ...

# %%
df.shape
# Out:
# (426, 14)

# %%
# Application software
as_df = df[df['Activity'] == "Application Software"]
sns.relplot(data = as_df, kind = 'scatter', x = '1_year', y = 'Revenue_gr_24', height=7, aspect=2.5)

plt.title('Revenue growth vs 1 Y performance for Application software')
plt.rcParams.update({"font.size": 6})


def label_point(x, y, val, ax: plt.Axes):
    a = pd.concat({'x': x, 'y': y, 'val': val }, axis = 1)
    for i , point in a.iterrows():
        ax.text(point['x'] -5, point['y'] + 0.01, str(point['val']) + ", " + str(point['x']))

label_point(as_df['1_year'], as_df['Revenue_gr_24'], as_df.Name, plt.gca())

# %%
#its_df = df[df['Activity'] == "Application Software"]

plt.subplots(figsize = (10,6))
sns.heatmap(as_df.corr(numeric_only = True), annot=True)
# Out:
# <Axes: >

# %%
s_df = df[df['Activity'] == "Semiconductors (NEC)"]

# %%
s_df.head()
# Out:
#          RIC                        Name              Activity  \
# 308    ARM.O            Arm Holdings PLC  Semiconductors (NEC)
# 309   NVDA.O                 NVIDIA Corp  Semiconductors (NEC)
# 310    AMD.O  Advanced Micro Devices Inc  Semiconductors (NEC)
# 311  AVGO.OQ                Broadcom Inc  Semiconductors (NEC)
# 312   MRVL.O      Marvell Technology Inc  Semiconductors (NEC)
#
#              MarketCap  EBITDA_M  1_year    YTD  EV_EBITDA_3F  EV_Revenues_1F  \
# 308     71,766,380,000     31.66     NaN  -6.85         32.36           22.88
# 309  1,351,337,000,000     29.18  231.35  10.48         21.01           22.73
# 310    236,767,517,465     24.52  107.01  -0.58         24.58           10.32
# 311    518,549,945,470     56.65   90.34  -0.77         14.21           10.76
# 312     56,780,360,000     31.86   67.08   8.90         21.21           10.95
#
#      EV_Revenues_2F  Revenue_gr_24  Revenue_gr_25  EBITDAgr25  \
# ...

# %%
# Semiconductors
sns.relplot(data = s_df, kind = 'scatter', x = '1_year', y = 'Revenue_gr_24', height=7, aspect=2.5)

plt.title('Revenue growth vs 1 Y performance for Semiconductors')
plt.rcParams.update({"font.size": 6})


def label_point(x, y, val, ax: plt.Axes):
    a = pd.concat({'x': x, 'y': y, 'val': val }, axis = 1)
    for i , point in a.iterrows():
        ax.text(point['x'] -5, point['y'] + 0.01, str(point['val']) + ", " + str(point['x']))

label_point(s_df['1_year'], s_df['Revenue_gr_24'], s_df.Name, plt.gca())
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# Application software
sns.pairplot(data = as_df)

# %%
# Semiconductors 
sns.pairplot(data = s_df)

# %%
# Semiconductors
plt.subplots(figsize = (10,6))
sns.heatmap(s_df.corr(numeric_only = True), annot=True)
# Out:
# <Axes: >

# %%
es_df = df[df['Activity'] == "Enterprise Software"]

sns.pairplot(data = es_df)

# %%
es_df = df[df['Activity'] == "Enterprise Software"]
# df = df.drop(['EV_Revenues_3F'], axis = 1)
plt.subplots(figsize = (10,6))
sns.heatmap(es_df.corr(numeric_only = True), annot=True)
# Out:
# <Axes: >

# %%
# Enterprise software
es_df = df[df['Activity'] == "Enterprise Software"]
sns.relplot(data = es_df, kind = 'scatter', x = '1_year', y = 'Revenue_gr_24', height=7, aspect=2.5)

plt.title('Revenue growth vs 1 Y performance for Enterprise software')
plt.rcParams.update({"font.size": 6})


def label_point(x, y, val, ax: plt.Axes):
    a = pd.concat({'x': x, 'y': y, 'val': val }, axis = 1)
    for i , point in a.iterrows():
        ax.text(point['x'] -5, point['y'] + 0.01, str(point['val']) + ", " + str(point['x']))

label_point(es_df['1_year'], es_df['Revenue_gr_24'], es_df.Name, plt.gca())

# %%
ccs_df = df[df['Activity'] == "Cloud Computing Services"]

plt.subplots(figsize = (10,6))
sns.heatmap(ccs_df.corr(numeric_only = True), annot=True)
# Out:
# <Axes: >

# %%
# Cloud computing services
ccs_df = df[df['Activity'] == "Cloud Computing Services"]
sns.relplot(data = ccs_df, kind = 'scatter', x = '1_year', y = 'Revenue_gr_24', height=7, aspect=2.5)

plt.title('Revenue growth vs 1 Y performance for Cloud Computing Services')
plt.rcParams.update({"font.size": 6})


def label_point(x, y, val, ax: plt.Axes):
    a = pd.concat({'x': x, 'y': y, 'val': val }, axis = 1)
    for i , point in a.iterrows():
        ax.text(point['x'] -5, point['y'] + 0.01, str(point['val']) + ", " + str(point['x']))

label_point(ccs_df['1_year'], ccs_df['Revenue_gr_24'], ccs_df.Name, plt.gca())

# %%
# IT Services & Consulting (NEC)
its_df = df[df['Activity'] == "IT Services & Consulting (NEC)"]
sns.relplot(data = its_df, kind = 'scatter', x = '1_year', y = 'Revenue_gr_24', height=7, aspect=2.5)

plt.title('Revenue growth vs 1 Y performance for IT Services & Consulting (NEC)')
plt.rcParams.update({"font.size": 6})


def label_point(x, y, val, ax: plt.Axes):
    a = pd.concat({'x': x, 'y': y, 'val': val }, axis = 1)
    for i , point in a.iterrows():
        ax.text(point['x'] -5, point['y'] + 0.01, str(point['val']) + ", " + str(point['x']))

label_point(its_df['1_year'], its_df['Revenue_gr_24'], its_df.Name, plt.gca())

# %%
#its_df = df[df['Activity'] == "IT Services & Consulting (NEC)"]

plt.subplots(figsize = (10,6))
sns.heatmap(its_df.corr(numeric_only = True), annot=True)
# Out:
# <Axes: >

# %%
# Online Services (NEC)
os_df = df[df['Activity'] == "Online Services (NEC)"]
sns.relplot(data = os_df, kind = 'scatter', x = '1_year', y = 'Revenue_gr_24', height=7, aspect=2.5)

plt.title('Revenue growth vs 1 Y performance for Online Services (NEC)')
plt.rcParams.update({"font.size": 6})


def label_point(x, y, val, ax: plt.Axes):
    a = pd.concat({'x': x, 'y': y, 'val': val }, axis = 1)
    for i , point in a.iterrows():
        ax.text(point['x'] -5, point['y'] + 0.01, str(point['val']) + ", " + str(point['x']))

label_point(os_df['1_year'], os_df['Revenue_gr_24'], os_df.Name, plt.gca())
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
#its_df = df[df['Activity'] == "Online Services (NEC)"]

plt.subplots(figsize = (10,6))
sns.heatmap(os_df.corr(numeric_only = True), annot=True)
# Out:
# <Axes: >

# %%
# Software (NEC)
sof_df = df[df['Activity'] == "Software (NEC)"]
sns.relplot(data = sof_df, kind = 'scatter', x = '1_year', y = 'Revenue_gr_24', height=7, aspect=2.5)

plt.title('Revenue growth vs 1 Y performance for Software (NEC)')
plt.rcParams.update({"font.size": 6})


def label_point(x, y, val, ax: plt.Axes):
    a = pd.concat({'x': x, 'y': y, 'val': val }, axis = 1)
    for i , point in a.iterrows():
        ax.text(point['x'] -5, point['y'] + 0.01, str(point['val']) + ", " + str(point['x']))

label_point(sof_df['1_year'], sof_df['Revenue_gr_24'], sof_df.Name, plt.gca())

# %%
#its_df = df[df['Activity'] == "Software (NEC)"]

plt.subplots(figsize = (10,6))
sns.heatmap(sof_df.corr(numeric_only = True), annot=True)
# Out:
# <Axes: >
