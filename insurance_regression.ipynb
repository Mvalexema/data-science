# %%
# The model explores how age affects the insurance costs

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
insur_data = pd.read_csv("insurance.csv")
insur_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Using iloc function to select data from the dataframe for plotting.  
x = insur_data.iloc[:,:1].values
y = insur_data.iloc[:,-1].values

# Checking the data.
print(x)
print(y)

# Drawing the scatter plot.
plt.scatter(x,y,color = 'r')
plt.xlabel('Age - Independent variable')b
plt.ylabel('Charges - Dependent variable')
plt.show()
# Out:
# [[19]
#  [18]
#  [28]
#  ...
#  [18]
#  [21]
#  [61]]
# [16884.924   1725.5523  4449.462  ...  1629.8335  2007.945  29141.3603]

# %%
# Linear model
insurance_charge_model = LinearRegression()
insurance_charge_model.fit(x,y)
# Out:
# LinearRegression()

# %%
# Prediction
unk_x = [[22]] 

x_pred = np.append(x, unk_x).reshape(-1,1)
y_pred = insurance_charge_model.predict(x_pred)

plt.scatter(x,y,color = 'r')
plt.plot(x_pred,y_pred,color = 'b')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

print("The charge should be:", insurance_charge_model.predict(unk_x))
# Out:
# The charge should be: [8835.78261673]
